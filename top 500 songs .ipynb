# %%
# to find the data set

# %%
import pandas as pd

# %%
from matplotlib import pyplot as plt

# %%
Tej = pd.read_csv('songs.csv')

# %%
Tej.head(10)
# Out:
#                 title                                        description  \
# 0         Shop Around  Robinson thought Barrett Strong should record ...
# 1         Buddy Holly  In the early 1990s, Cuomo had an awkward girlf...
# 2            Miss You  The Stones were in Toronto, rehearsing for the...
# 3          The Rising  Springsteen wrote the track about 9/11, taking...
# 4    Running on Empty  The Running on Empty album was Browne's grand ...
# 5         Brown Sugar  The Stones take on slavery, sadomasochism, int...
# 6    Ignition (Remix)  R. Kelly's automotive metaphors for booty-knoc...
# 7     Time to Pretend  The rhythm was inspired by the wriggling of a ...
# 8      I Will Survive  In 1979, Gaynor's career was falling apart. Do...
# 9  I Love Rock N Roll  Attempting to jump-start a solo career after h...
#
#                                  appears on                            artist  \
# 0          The Ultimate Collection (Motown)  Smokey Robinson and the Miracles
# ...

# %%
Tej.tail(10)
# Out:
#                         title  \
# 490       The Great Pretender
# 491           The Loco-Motion
# 492            Spanish Harlem
# 493  That Lady (Part 1 and 2)
# 494        Candle in the Wind
# 495           California Love
# 496                  La Bamba
# 497         Piece of My Heart
# 498                 Jim Dandy
# 499             Runaround Sue
#
#                                            description  \
# 490  Heirs to the crooning style of the Ink Spots a...
# 491  At 17, Eva Boyd was hired to baby-sit King and...
# 492  Just split from the Drifters, King was eager t...
# 493  In 1969, the Isleys added younger brothers Ern...
# 494  John’s Marilyn Monroe tribute was a U.K. hit i...
# 495  When 2Pac left jail in October 1995, after ser...
# 496  Valens' version of this traditional Mexican we...
# 497  The original was sung by Erma Franklin, Aretha...
# 498  Baker was a Chicago singer with a pedigree — h...
# 499  Dion was a country-music fan and member of a g...
#
# ...

# %%
Tej.describe()
# Out:
#              title                                        description  \
# count          500                                                500
# unique         150                                                150
# top     White Room  This anthem was written on an ironing board in...
# freq             6                                                  6
#
#                               appears on      artist              writers  \
# count                                500         500                  500
# unique                               139         125                  132
# top     The Ultimate Collection (Motown)  Elton John  John, Bernie Taupin
# freq                                  20          18                   18
#
#            producer        released         streak
# count           500             500            494
# unique          130             147            106
# top     Gus Dudgeon  July '79, Epic  Did Not Chart
# ...

# %%
Tej.iloc[1:5,3:7]
# Out:
#                artist                      writers           producer  \
# 1              Weezer                 Rivers Cuomo         Ric Ocasek
# 2  The Rolling Stones  Mick Jagger, Keith Richards  The Glimmer Twins
# 3   Bruce Springsteen                  Springsteen    Brendan O'Brien
# 4      Jackson Browne                       Browne             Browne
#
#                   released
# 1            Aug. '94, DGC
# 2  May '78, Rolling Stones
# 3       July '02, Columbia
# 4         Jan. '77, Asylum

# %%
Tej.loc[1:8,("released")]
# Out:
# 1                Aug. '94, DGC
# 2      May '78, Rolling Stones
# 3           July '02, Columbia
# 4             Jan. '77, Asylum
# 5    April '71, Rolling Stones
# 6               Oct. '02, Jive
# 7            Jan '08, Columbia
# 8            Dec. '78, Polydor
# Name: released, dtype: object

# %%
plt.hist(Tej['released'])
plt.show()

# %%
plt.hist(Tej['writers'])
# Out:
# (array([34., 44., 42., 26., 38., 26., 32., 90., 84., 84.]),
#  array([  0. ,  13.1,  26.2,  39.3,  52.4,  65.5,  78.6,  91.7, 104.8,
#         117.9, 131. ]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(Tej['artist'])
# Out:
# (array([30., 26., 60., 32., 46., 38., 30., 82., 78., 78.]),
#  array([  0. ,  12.4,  24.8,  37.2,  49.6,  62. ,  74.4,  86.8,  99.2,
#         111.6, 124. ]),
#  <a list of 10 Patch objects>)
